# %%
import matplotlib.pyplot as plt

# Define models and categorize them
thinking_models = [
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]",
]

no_thinking_models = [
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]",
]

qwen_model = "Qwen-32B-Instruct"

# Pass@K values
k_values_full = [1, 2, 4, 8, 16, 32, 64]

# Pass@K results (Ensure k-values dynamically adjust per model)
pass_at_k_results = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": [69.792, 78.508, 83.036, 85.636, 87.928, 90],
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]": [33.125, 41.539, 48.939, 54.823, 59.231, 63.333],
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]": [31.25, 36.7, 41.596, 46.488, 52.149, 60],
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]": [12.812, 18.884, 24.737, 30.138, 35.285, 40],
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": [31.771, 44.458, 55.791, 64.823, 72.032, 78.06, 83.33],
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]": [25.859, 36.406, 45.973, 54.082, 61.767, 69.737, 77.303],
    "Qwen-32B-Instruct": [14.896, 19.439, 24.17, 29.536, 35.157, 40.767, 46.667],
}

# Define color scheme (Blue for Thinking, Red for No-Thinking, Purple for Qwen)
color_map = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": "#1f77b4",  # Dark Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]": "#66b3ff",  # Light Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]": "#0057b8",  # Royal Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]": "#4682b4",  # Steel Blue
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": "#d62728",  # Dark Red
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]": "#ff6666",  # Light Red
    "Qwen-32B-Instruct": "#9467bd",  # Purple
}

# Plot results
plt.figure(figsize=(10, 6))

for model, pass_at_k in pass_at_k_results.items():
    k_values = k_values_full[:len(pass_at_k)]  # Dynamically match k-values
    plt.plot(k_values, pass_at_k, marker='o', linestyle='-', color=color_map[model], label=model)

plt.xlabel("K")
plt.ylabel("Accuracy (%)")
title = "Pass@K Comparison Across Models (Grouped by Thinking/No-Thinking)"
plt.title(title)
plt.legend(loc="lower right", fontsize=8)
plt.grid(True)
plt.xticks(k_values_full)  # Consistent x-axis labels
safe_filename = title.replace(" ", "_").replace("@", "at").replace("(", "").replace(")", "").replace("/", "_")
plt.savefig(f"{safe_filename}.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# Define models and token usage
models = [
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]",
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]",
    "Qwen-32B-Instruct"
]

# Token usage statistics
token_usage = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": 10376.811,
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]": 3895.998,
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]": 3471.465,
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]": 2049.519,
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": 4027.805,
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]": 1877.664,
    "Qwen-32B-Instruct": 919.919
}

# Accuracy values (using Pass@64 as the final accuracy metric)
accuracy = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": {1:69.792},
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]": {1:33.125, 32:53.33},
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]": {1:31.25, 32:43.33},
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]": {1:12.812, 32:20},
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": {1:31.771, 32:50},
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]": {1:25.859, 32:46.67},
    "Qwen-32B-Instruct": {1:14.896}
}

# Define color scheme (Blue for Thinking, Red for No-Thinking, Purple for Qwen)
color_map = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": "#1f77b4",  # Dark Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]": "#66b3ff",  # Light Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]": "#0057b8",  # Royal Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]": "#4682b4",  # Steel Blue
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": "#d62728",  # Dark Red
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]": "#ff6666",  # Light Red
    "Qwen-32B-Instruct": "#9467bd",  # Purple
}

# Scatter plot for Token Usage vs. Accuracy
plt.figure(figsize=(8, 6))
legend_added = {}
for model in models:
    for k, acc in accuracy[model].items():
        marker_size = 200 if k == 32 else 80
        label = model if model not in legend_added else None
        plt.scatter(token_usage[model], acc, s=marker_size, color=color_map[model], label=label)
        legend_added[model] = True

plt.xlabel("Token Usage")
plt.ylabel("Accuracy (%)")
title = "AIME 24-Token Usage vs. Accuracy Across Models (Pass@1 and Cons@32)"
plt.title(title)
plt.legend(loc="lower right", fontsize=8)
plt.grid(True)
plt.plot([token_usage["DeeepSeek-R1-Distill-Qwen-32B [Thinking]"], token_usage["Qwen-32B-Instruct"]], 
         [accuracy["DeeepSeek-R1-Distill-Qwen-32B [Thinking]"][1], accuracy["Qwen-32B-Instruct"][1]], 
         'k--',  # black dashed line
         alpha=0.5)
safe_filename = title.replace(" ", "_").replace("@", "at").replace("(", "").replace(")", "").replace("/", "_")
plt.savefig(f"{safe_filename}.png")
plt.savefig(f"{title}.png")
plt.show()

# %%
# AIME 25

import matplotlib.pyplot as plt

# Define models and categorize them
thinking_models = [
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]",
]

no_thinking_models = [
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]",
]

qwen_model = "Qwen-32B-Instruct"

# Pass@K values
k_values_full = [1, 2, 4, 8, 16, 32, 64]

# Pass@K results (Ensure k-values dynamically adjust per model)
pass_at_k_results = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": [53.542, 63.945, 71.461, 75.663, 78.358, 80],
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]": [24.896, 27.554, 29.078, 31.29, 35.054, 40],
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]": [21.875, 25.517, 27.334, 28.332, 30.333, 33.333],
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]": [8.542, 12.816, 17.167, 21.501, 25.712, 30],
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": [21.042, 30.146, 39.738, 49.877, 60.179, 69.36, 76.667],
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]": [17.943, 24.73, 30.835, 36.366, 41.678, 47.291, 53.733],
    "Qwen-32B-Instruct": [13.333, 19.583, 24.795, 28.034, 30, 33.33],
}

# Define color scheme (Blue for Thinking, Red for No-Thinking, Purple for Qwen)
color_map = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": "#1f77b4",  # Dark Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]": "#66b3ff",  # Light Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]": "#0057b8",  # Royal Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]": "#4682b4",  # Steel Blue
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": "#d62728",  # Dark Red
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]": "#ff6666",  # Light Red
    "Qwen-32B-Instruct": "#9467bd",  # Purple
}

# Plot results
plt.figure(figsize=(10, 6))

for model, pass_at_k in pass_at_k_results.items():
    k_values = k_values_full[:len(pass_at_k)]  # Dynamically match k-values
    plt.plot(k_values, pass_at_k, marker='o', linestyle='-', color=color_map[model], label=model)

plt.xlabel("K")
plt.ylabel("Accuracy (%)")
title = "Pass@K Comparison Across Models (Grouped by Thinking/No-Thinking) (AIME 25)"
plt.title(title)
plt.legend(loc="lower right", fontsize=8)
plt.grid(True)
plt.xticks(k_values_full)  # Consistent x-axis labels
safe_filename = title.replace(" ", "_").replace("@", "at").replace("(", "").replace(")", "").replace("/", "_")
plt.savefig(f"{safe_filename}.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# Define models and token usage
models = [
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]",
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]",
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]",
    "Qwen-32B-Instruct"
]

# Token usage statistics
token_usage = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": 12533.991,
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]": 3884.785,
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]": 3460.535,
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]": 2047.726,
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": 3640.772,
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]": 1651.207,
    "Qwen-32B-Instruct": 907.459
}

# Accuracy values (using Pass@64 as the final accuracy metric)
accuracy = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": {1:53.542},
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]": {1:24.896, 32:30},
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]": {1:21.875, 32:26.67},
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]": {1:8.542, 32:23.33},
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": {1:21.042, 32:40},
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]": {1:17.943, 32:30},
    "Qwen-32B-Instruct": {1:13.333, 32:19.583}
}

# Define color scheme (Blue for Thinking, Red for No-Thinking, Purple for Qwen)
color_map = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": "#1f77b4",  # Dark Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 4000)]": "#66b3ff",  # Light Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 3500)]": "#0057b8",  # Royal Blue
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking (With budget force 2000)]": "#4682b4",  # Steel Blue
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": "#d62728",  # Dark Red
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking (With budget force 3500)]": "#ff6666",  # Light Red
    "Qwen-32B-Instruct": "#9467bd",  # Purple
}

# Scatter plot for Token Usage vs. Accuracy
plt.figure(figsize=(8, 6))
legend_added = {}
for model in models:
    for k, acc in accuracy[model].items():
        marker_size = 200 if k == 32 else 80
        label = model if model not in legend_added else None
        plt.scatter(token_usage[model], acc, s=marker_size, color=color_map[model], label=label)
        legend_added[model] = True

plt.xlabel("Token Usage")
plt.ylabel("Accuracy (%)")
title = "AIME 25-Token Usage vs. Accuracy Across Models (Pass@1 and Cons@32)"
plt.title(title)
plt.legend(loc="lower right", fontsize=8)
plt.grid(True)
plt.plot([token_usage["DeeepSeek-R1-Distill-Qwen-32B [Thinking]"], token_usage["Qwen-32B-Instruct"]], 
         [accuracy["DeeepSeek-R1-Distill-Qwen-32B [Thinking]"][1], accuracy["Qwen-32B-Instruct"][1]], 
         'k--',  # black dashed line
         alpha=0.5)
safe_filename = title.replace(" ", "_").replace("@", "at").replace("(", "").replace(")", "").replace("/", "_")
plt.savefig(f"{safe_filename}.png")
plt.savefig(f"{title}.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define models
models = [
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]",
    "Qwen-32B-Instruct"
]

# Token usage statistics
token_usage = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": 5397.583,
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": 1825.336,
    "Qwen-32B-Instruct": 793.975
}

# Pass@K values
k_values = [1, 2, 4, 8, 16, 32, 64]
pass_at_k_results = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": [94.453, 97.712, 99.377, 99.949, 100, 100, 100],
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": [66.191, 79.13, 87.535, 92.31, 94.694, 95.59, 96.25],
    "Qwen-32B-Instruct": [61.562, 71.562, 79.412, 84.921, 90, 95]  # Missing Pass@128
}

# Define colors
color_map = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": "#1f77b4",  # Dark Blue
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": "#d62728",  # Dark Red
    "Qwen-32B-Instruct": "#9467bd",  # Purple
}

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot Pass@K results
for model in models:
    valid_k_values = k_values[:len(pass_at_k_results[model])]  # Adjust k-values to match available data
    valid_pass_at_k = pass_at_k_results[model]  # Ensure same length for x and y
    
    ax1.plot(valid_k_values, valid_pass_at_k, marker='o', linestyle='-', color=color_map[model], label=model)

ax1.set_xlabel("Pass@K")
ax1.set_ylabel("Accuracy (%)", color="black")
title = "Pass@K Comparison Across Models (AMC23)"
ax1.set_title(title)

# Create a secondary y-axis for token usage (Bar Chart)
ax2 = ax1.twinx()
bar_positions = np.arange(len(models))
bar_width = 0.3

ax2.set_ylabel("Token Usage")

# Adjust x-axis labels and legends
ax1.set_xticks(k_values)
ax1.legend(loc="upper left", fontsize=8)
ax2.legend(loc="upper right", fontsize=8)

plt.grid(True)

filename = title.replace(" ", "_").replace("@", "at").replace("(", "").replace(")", "").replace("/", "_")
plt.savefig(f"{filename}.png")

plt.show()
# Out:
# /tmp/ipykernel_12859/3278635561.py:58: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc="upper right", fontsize=8)

# %%
# GPQA

import matplotlib.pyplot as plt
import numpy as np

# Define models
models = [
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]",
    "Qwen-32B-Instruct"
]

# Token usage statistics
token_usage = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": 5827.858,
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": 1154.042,
    "Qwen-32B-Instruct": 578.11
}

# Pass@K values
k_values = [1, 2, 4, 8, 16, 32, 64]
pass_at_k_results = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": [62.997, 72.714, 80.429, 86.076, 89.762, 91.95, 93.434],
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": [47.854, 63.001, 75.37, 84.443, 90.909, 94.44, 95.45],
    "Qwen-32B-Instruct": [46.307, 58.472, 69.45, 78.097, 83.838, 91.41, 95.45]  # Missing Pass@256
}

# Define colors
color_map = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": "#1f77b4",  # Dark Blue
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": "#d62728",  # Dark Red
    "Qwen-32B-Instruct": "#9467bd",  # Purple
}

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot Pass@K results
for model in models:
    valid_k_values = k_values[:len(pass_at_k_results[model])]  # Adjust k-values to match available data
    valid_pass_at_k = pass_at_k_results[model]  # Ensure same length for x and y
    
    ax1.plot(valid_k_values, valid_pass_at_k, marker='o', linestyle='-', color=color_map[model], label=model)

ax1.set_xlabel("Pass@K")
ax1.set_ylabel("Accuracy (%)", color="black")

title = "Pass@K Comparison Across Models (GPQA)"
ax1.set_title(title)

# Create a secondary y-axis for token usage (Bar Chart)
ax2 = ax1.twinx()
bar_positions = np.arange(len(models))
bar_width = 0.3

ax2.set_ylabel("Token Usage")

# Adjust x-axis labels and legends
ax1.set_xticks(k_values)
ax1.legend(loc="lower right", fontsize=8)
ax2.legend(loc="upper right", fontsize=8)

plt.grid(True)
filename = title.replace(" ", "_").replace("@", "at").replace("(", "").replace(")", "").replace("/", "_")
plt.savefig(f"{filename}.png")
plt.show()
# Out:
# /tmp/ipykernel_12859/501089188.py:61: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc="upper right", fontsize=8)

# %%
# Olympiad Bench

import matplotlib.pyplot as plt
import numpy as np

# Define models
models = [
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]",
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]",
    "Qwen-32B-Instruct"
]

# Token usage statistics
token_usage = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": 8614.65,
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": 1960.024,
    "Qwen-32B-Instruct": 829.312
}

# Pass@K values
k_values = [1, 2, 4, 8, 16]
pass_at_k_results = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": [54.108, 63.722, 71.364, 76.817, 80.712],
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": [48.386, 57.993, 65.762, 71.077, 74.332],
    "Qwen-32B-Instruct": [46.875, 53.996, 60.011, 64.862, 68.694]  # Missing Pass@256
}

# Define colors
color_map = {
    "DeeepSeek-R1-Distill-Qwen-32B [Thinking]": "#1f77b4",  # Dark Blue
    "DeeepSeek-R1-Distill-Qwen-32B [No-Thinking]": "#d62728",  # Dark Red
    "Qwen-32B-Instruct": "#9467bd",  # Purple
}

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot Pass@K results
for model in models:
    valid_k_values = k_values[:len(pass_at_k_results[model])]  # Adjust k-values to match available data
    valid_pass_at_k = pass_at_k_results[model]  # Ensure same length for x and y
    
    ax1.plot(valid_k_values, valid_pass_at_k, marker='o', linestyle='-', color=color_map[model], label=model)

ax1.set_xlabel("Pass@K")
ax1.set_ylabel("Accuracy (%)", color="black")

title = "Pass@K Comparison Across Models (Olympiad Bench)"
ax1.set_title(title)

# Create a secondary y-axis for token usage (Bar Chart)
ax2 = ax1.twinx()
bar_positions = np.arange(len(models))
bar_width = 0.3

ax2.set_ylabel("Token Usage")

# Adjust x-axis labels and legends
ax1.set_xticks(k_values)
ax1.legend(loc="lower right", fontsize=8)
ax2.legend(loc="upper right", fontsize=8)

plt.grid(True)
filename = title.replace(" ", "_").replace("@", "at").replace("(", "").replace(")", "").replace("/", "_")
plt.savefig(f"{filename}.png")
plt.show()
# Out:
# /tmp/ipykernel_12859/998381444.py:61: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc="upper right", fontsize=8)
